# %%
# from fastapi import FastAPI
# from pydantic import BaseModel
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import joblib
import matplotlib.pyplot as plt

# import joblib
# from sklearn.neighbors import NearestNeighbors
# Out:
# C:\Users\achyu\MachineLearning\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import re

df = pd.read_csv("vehicles_dataset.csv")

df.dropna(inplace=True)
#df = df[df["fuel"] == "Electric"]
df.columns = df.columns.str.strip().str.lower()

def strip_trim_from_name(row, name_col="name", trim_col="trim"):
    name = str(row.get(name_col, "") or "")
    trim = row.get(trim_col, "")
    if pd.isna(trim) or trim is None:
        return name

    trim = str(trim).strip()
    if trim == "":
        return name

    # escape regex metacharacters in trim
    esc = re.escape(trim)

    # pattern:
    #  - match " - TRIM" or "— TRIM" or ": TRIM"
    #  - match "(TRIM)"
    #  - match trim as a whole word (so single-letter 'S' won't match 'Soul')
    pattern = rf'(?i)(?:\s*[-–—:]\s*{esc}|\s*\(\s*{esc}\s*\)|\b{esc}\b)'

    # remove occurrences that match the pattern
    new_name = re.sub(pattern, ' ', name)

    # collapse multiple spaces and trim leading/trailing whitespace
    new_name = re.sub(r'\s+', ' ', new_name).strip()

    return new_name


df["drivetrain"].unique()
# Out:
# array(['Four-wheel Drive', 'All-wheel Drive', 'Rear-wheel Drive',
#        'Front-wheel Drive'], dtype=object)

# %%
#df2 = pd.read_csv('Safercar_data.csv')

# Convert to numeric (in case of 'Not Rated' or strings)
#df2['OVERALL_STARS'] = pd.to_numeric(df2['OVERALL_STARS'], errors='coerce')

# Drop rows with missing or invalid ratings
#df2 = df2.dropna(subset=['OVERALL_STARS'])

# Group by make and calculate the average
#average_ratings = df2.groupby('MAKE')['OVERALL_STARS'].mean().sort_values(ascending=False).to_dict()


#print(average_ratings)

# %%
import pandas as pd
import requests
from IPython.display import HTML

# Take input and filter
#make = input("Enter make: ").strip().lower()
#model = input("Enter model: ").strip().lower()
#yr = input("Enter model year: ").strip().lower()

#matches = df2[(df2['MODEL'].str.lower().str.contains(model, na=False)) 
             # & (df2['MODEL_YR'] == int(yr))][['MAKE', 'MODEL', 'MODEL_YR', 'OVERALL_STARS']]
#if matches.shape[0] > 0:
   # display(matches)
#else:
  #  print("Requested car not found")

#display(HTML(f'<a href=https://cars.usnews.com/cars-trucks/{make}/{model}/{yr} target="_blank">{yr} {make.capitalize()} {model.capitalize()}</a>'))

# %%
import re

def clean_model_name(model: str) -> str:
    # Define forbidden words
    forbidden_words = {
        "se", "le", "xe", "xle", "ls", "lxs", "ex", "limited", "ultimate", "advanced", "premium", "standard", "range", "touring",
        "sport", "luxury", "pure", "electric", "twin", "performance", "plus", "base", "select", "light", "long", 
        "gt", "a-spec", "edition", "platinum", "sel", "2lt", "lt", "sxt", "sv", "s", "14t", "l", "latitude", "preferred", "active", 
        "sle", "r/t", "1500", "2500", "3500"
    }
    
    # Normalize and split
    words = model.lower().split()
    
    # Filter out forbidden words and numeric tokens (integers or decimals)
    filtered_words = [
        w for w in words
        if w not in forbidden_words and not re.match(r"\d+(\.\d+)", w)
    ]
        
    # Join back into slug
    return "-".join(filtered_words)

# Test cases
#print(clean_model_name("Ioniq 5 SE Standard Range"))                   # → "ioniq-5"
#print(clean_model_name("C40 Recharge Pure Electric Twin Ultimate"))   # → "c40-recharge"
#print(clean_model_name("Electrified GV70 Advanced"))                  # → "electrified-gv70"
#print(clean_model_name("CR-V 1.5T Touring"))                           # → "cr-v"
#print(clean_model_name("CX-30 2.5 S Premium"))     
#print(clean_model_name("GMC Terrain SLE"))

# %%
features = ["price", "mileage", "fuel", "cylinders", "body", "drivetrain", "doors"]
X = df[features].copy()

X = pd.get_dummies(X, columns=["fuel", "body", "drivetrain"], drop_first=True)

encoded_features = X.columns.tolist()
#("Encoded features:", encoded_features)

# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

inertia = []
K = range(2, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(K, inertia, 'bx-')
plt.xlabel("Number of clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal k")
plt.show()

# Cluster (k found using elbow method)
kmeans = KMeans(n_clusters=6, random_state=42)
df["category"] = kmeans.fit_predict(X_scaled)

# Add the new encoded columns to the original df
for col in X.columns:
    df[col] = X[col]

# Group by clusters
print(df.groupby("category")[encoded_features].mean())

# Mapping of cluster numbers -> labels
cluster_labels = {
    0: "Standard Premium SUV",
    1: "High-End Truck/Performance Vehicle",
    2: "New Sedan (Commuter/Mid-Range)",
    3: "Budget New Compact Sedan",
    4: "New Efficient Hatchback/Compact",
    5: "New Premium Van/High-Power Utility"
}

# Apply mapping
df["category_label"] = df["category"].map(cluster_labels)

# Preview
print(df[["name", "price", "mileage", "cylinders", "year", "doors", "category", "category_label"]].head(30))
# Out:
#                  price     mileage  cylinders     doors  fuel_E85 Flex Fuel  \
# category
# 0         45945.994962  108.254408   4.921914  4.000000            0.000000
# 1         49655.433333   22.100000   3.983333  4.000000            0.000000
# 2         57883.631579  179.684211   5.947368  2.763158            0.078947
# 3         34218.686275   13.372549   4.588235  4.000000            0.000000
# 4         41418.500000    8.166667   4.000000  4.000000            0.000000
# 5         60622.826087   50.514493   6.130435  4.000000            0.000000
#
#           fuel_Electric  fuel_Gasoline  fuel_Hybrid  fuel_PHEV Hybrid Fuel  \
# category
# 0              0.000000       1.000000     0.000000               0.000000
# 1              0.008333       0.000000     0.858333               0.133333
# 2              0.000000       0.736842     0.000000               0.000000
# 3              0.000000       0.764706     0.235294               0.000000
# 4              0.000000       1.000000     0.000000               0.000000
# 5              0.000000       0.514493     0.036232               0.000000
#
#           body_Convertible  body_Hatchback  body_Minivan  body_Passenger Van  \
# category
# 0                 0.000000             0.0      0.002519            0.015113
# 1                 0.000000             0.0      0.000000            0.008333
# 2                 0.026316             0.0      0.000000            0.026316
# 3                 0.000000             0.0      0.000000            0.000000
# 4                 0.000000             1.0      0.000000            0.000000
# 5                 0.000000             0.0      0.000000            0.000000
#
#           body_Pickup Truck  body_SUV  body_Sedan  \
# category
# 0                  0.000000  0.979849         0.0
# 1                  0.000000  0.991667         0.0
# 2                  0.184211  0.026316         0.0
# 3                  0.000000  0.000000         1.0
# 4                  0.000000  0.000000         0.0
# 5                  1.000000  0.000000         0.0
#
#           drivetrain_Four-wheel Drive  drivetrain_Front-wheel Drive  \
# category
# 0                            0.360202                      0.143577
# 1                            0.266667                      0.050000
# 2                            0.157895                      0.315789
# 3                            0.000000                      0.666667
# 4                            0.000000                      0.166667
# 5                            0.797101                      0.000000
#
#           drivetrain_Rear-wheel Drive
# category
# 0                            0.027708
# 1                            0.000000
# 2                            0.447368
# 3                            0.235294
# 4                            0.000000
# 5                            0.028986
#                                               name    price  mileage  \
# 0                     2024 Jeep Wagoneer Series II  74600.0     10.0
# 1                  2024 Jeep Grand Cherokee Laredo  50170.0      1.0
# 3                       2023 Dodge Durango Pursuit  46835.0     32.0
# 4                            2024 RAM 3500 Laramie  81663.0     10.0
# 5                      2024 Nissan Murano Platinum  46000.0   3838.0
# 6                          2024 Jeep Wagoneer Base  63862.0      5.0
# 7                2024 Ford F-350 Lariat Super Duty  89978.0     15.0
# 9                2024 Jeep Grand Cherokee Altitude  42773.0     20.0
# 10                      2024 Jeep Compass Latitude  37743.0      0.0
# 11                         2024 RAM 3500 Tradesman  60904.0    532.0
# 12            2024 Hyundai Santa Cruz 2.5T Limited  43419.0      1.0
# 13               2024 Jeep Grand Cherokee Altitude  44022.0     12.0
# 15                2024 Hyundai Santa Cruz 2.5T XRT  38574.0     12.0
# 16                     2024 Nissan Murano Platinum  48000.0     87.0
# 17                   2024 Ford Explorer Timberline  53190.0     15.0
# 18                    2024 Volkswagen Taos 1.5T SE  32751.0     25.0
# 19                    2024 Volkswagen Jetta 1.4T S  24348.0     13.0
# 20                         2024 RAM 3500 Tradesman  65221.0    344.0
# 21                           2024 Dodge Hornet R/T  39491.0      5.0
# 22                         2024 Hyundai Tucson SEL  30305.0     11.0
# 24                2024 Hyundai Santa Cruz 2.5L SEL  33160.0      1.0
# 25                          2024 Ford Explorer XLT  40940.0      7.0
# 26                       2024 Jeep Compass Limited  34084.0     12.0
# 29                         2024 RAM 2500 Tradesman  58855.0      0.0
# 30                           2024 Nissan Murano SV  39867.0      2.0
# 31  2024 Ford Transit-250 148 WB Medium Roof Cargo  53595.0     10.0
# 32          2023 Jeep Grand Cherokee 4xe Trailhawk  59547.0    185.0
# 34                   2024 Volkswagen Jetta 1.4T SE  27175.0      5.0
# 36               2024 Chevrolet Silverado 1500 RST  58610.0      0.0
# 37                              2024 Kia Seltos EX  29640.0     16.0
#
#     cylinders  year  doors  category                      category_label
# 0         6.0  2024    4.0         0                Standard Premium SUV
# 1         6.0  2024    4.0         0                Standard Premium SUV
# 3         8.0  2023    4.0         0                Standard Premium SUV
# 4         6.0  2024    4.0         5  New Premium Van/High-Power Utility
# 5         6.0  2024    4.0         0                Standard Premium SUV
# 6         6.0  2024    4.0         0                Standard Premium SUV
# 7         8.0  2024    4.0         5  New Premium Van/High-Power Utility
# 9         6.0  2024    4.0         0                Standard Premium SUV
# 10        4.0  2024    4.0         0                Standard Premium SUV
# 11        6.0  2024    4.0         5  New Premium Van/High-Power Utility
# 12        4.0  2024    4.0         5  New Premium Van/High-Power Utility
# 13        6.0  2024    4.0         0                Standard Premium SUV
# 15        4.0  2024    4.0         5  New Premium Van/High-Power Utility
# 16        6.0  2024    4.0         0                Standard Premium SUV
# 17        4.0  2024    4.0         0                Standard Premium SUV
# 18        4.0  2024    4.0         0                Standard Premium SUV
# 19        4.0  2024    4.0         3            Budget New Compact Sedan
# 20        6.0  2024    4.0         5  New Premium Van/High-Power Utility
# 21        4.0  2024    4.0         1  High-End Truck/Performance Vehicle
# 22        4.0  2024    4.0         0                Standard Premium SUV
# 24        4.0  2024    4.0         5  New Premium Van/High-Power Utility
# 25        4.0  2024    4.0         0                Standard Premium SUV
# 26        4.0  2024    4.0         0                Standard Premium SUV
# 29        8.0  2024    4.0         5  New Premium Van/High-Power Utility
# 30        6.0  2024    4.0         0                Standard Premium SUV
# 31        6.0  2024    3.0         2      New Sedan (Commuter/Mid-Range)
# 32        4.0  2023    4.0         1  High-End Truck/Performance Vehicle
# 34        4.0  2024    4.0         3            Budget New Compact Sedan
# 36        8.0  2024    4.0         5  New Premium Van/High-Power Utility
# 37        4.0  2024    4.0         0                Standard Premium SUV
